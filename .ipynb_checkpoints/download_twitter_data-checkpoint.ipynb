# %% [markdown]
# Import libraries and key to access twitter. Keys and tokens can be gerated with an twitter account at https://developer.twitter.com/en/portal/dashboard

# %%
from keys import *
import tweepy
import pandas as pd
import requests

# %% [markdown]
# create client to access the twitter API
# Following tutorial: https://www.kirenz.com/post/2021-12-10-twitter-api-v2-tweepy-and-pandas-in-python/twitter-api-v2-tweepy-and-pandas-in-python/

# %%
client = tweepy.Client( bearer_token=bearer_token, 
                        consumer_key=consumer_key, 
                        consumer_secret=consumer_secret, 
                        access_token=access_token, 
                        access_token_secret=access_token_secret, 
                        return_type = requests.Response,
                        wait_on_rate_limit=True)

# %% [markdown]
# How to create queries https://medium.com/@robguilarr/making-queries-to-twitter-api-on-tweepy-66afeb7184a4

# %% [markdown]
# ToDO so schreiben das queries aus Suchwörtern aus zwei Listen abgefragr werden und Duplicate entfernt werden.
# Anschließend müssen Duplicate entfernt werden
#
# Bahn Bezug:
# regio
# Zug
# sbahn
# ubahn
# Stadtbahn
# Regionalbahn
# Straßenbahn
# Tram
# Bus
# Fernbus
# Stadtbus
# bahn
# ÖPNV
# ICE
# IC
# RE
#
# Fahrrad Bezug:
# Fahrrad
# rad
# bike
# ebike
# Elektrorad
# Elektrobike
# Elektrofahrrad
# pedelec
# velo
# Mountainbike
# Trekkingbike
# Radl

# %%
def get_tweets(query, max_results):
    tweets = client.search_recent_tweets(query=query, 
                                        tweet_fields=['attachments',
                                                        'author_id',
                                                        'context_annotations',
                                                        'conversation_id',
                                                        'created_at',
                                                        'geo',
                                                        'id',
                                                        'in_reply_to_user_id',
                                                        'lang',
                                                        'public_metrics',
                                                        'referenced_tweets',
                                                        'text'],
                                         max_results=max_results)
    return tweets

# %%
keywords = {'bahn_context':['regio',
                            'Zug',
                            'sbahn',
                            'ubahn',
                            'Stadtbahn',
                            'Regionalbahn',
                            'Straßenbahn',
                            'Tram',
                            'Bus',
                            'Fernbus',
                            'Stadtbus',
                            'bahn',
                            'ÖPNV',
                            'ICE',
                            'IC',
                            'RE'],
            'bike_context':['Fahrrad',
                            'rad',
                            'bike',
                            'ebike',
                            'Elektrorad',
                            'Elektrobike',
                            'Elektrofahrrad',
                            'pedelec',
                            'velo',
                            'Mountainbike',
                            'Trekkingbike',
                            'Radl']
           }

# %%
# 192 Permutationen

max_results = 100 # maximum is 100 due to ESSENTIAL access 
tweets_data = pd.DataFrame()
for first_keyword in keywords['bahn_context']:
    for second_keyword in keywords['bike_context']:
        query = first_keyword + ' ' + second_keyword
        tweets = get_tweets(query,max_results)
        # Save data as dictionary
        tweets_dict = tweets.json()
        # check if tweets where found for this query
        if 'data' in tweets_dict:
            # Extract "data" value from dictionary
            new_tweet_data = tweets_dict['data']
            # Transform to pandas Dataframe
            df_new_tweet_data = pd.json_normalize(new_tweet_data)
            df_new_tweet_data['query'] = query
            # concat dataframes with previously loaded data
            tweets_data = pd.concat([tweets_data, df_new_tweet_data])
        else:
            print('query', query, 'returned no results')

print(len(tweets_data),'tweets where found with', tweets_data['id'].nunique(), 'unique tweet_ids')
# Out:
# query regio ebike returned no results
# query regio Elektrorad returned no results
# query regio Elektrobike returned no results
# query regio Elektrofahrrad returned no results
# query regio pedelec returned no results
# query regio Trekkingbike returned no results
# query regio Radl returned no results
# query Zug ebike returned no results
# query Zug Elektrorad returned no results
# query Zug Elektrobike returned no results
# query Zug Elektrofahrrad returned no results
# query Zug pedelec returned no results
# query Zug Mountainbike returned no results
# query Zug Trekkingbike returned no results
# query sbahn bike returned no results
# query sbahn ebike returned no results
# query sbahn Elektrorad returned no results
# query sbahn Elektrobike returned no results
# query sbahn Elektrofahrrad returned no results
# query sbahn pedelec returned no results
# query sbahn velo returned no results
# query sbahn Mountainbike returned no results
# query sbahn Trekkingbike returned no results
# query sbahn Radl returned no results
# query ubahn ebike returned no results
# query ubahn Elektrorad returned no results
# query ubahn Elektrobike returned no results
# query ubahn Elektrofahrrad returned no results
# query ubahn pedelec returned no results
# query ubahn velo returned no results
# query ubahn Mountainbike returned no results
# query ubahn Trekkingbike returned no results
# query ubahn Radl returned no results
# query Stadtbahn rad returned no results
# query Stadtbahn bike returned no results
# query Stadtbahn ebike returned no results
# query Stadtbahn Elektrorad returned no results
# query Stadtbahn Elektrobike returned no results
# query Stadtbahn Elektrofahrrad returned no results
# query Stadtbahn pedelec returned no results
# query Stadtbahn velo returned no results
# query Stadtbahn Mountainbike returned no results
# query Stadtbahn Trekkingbike returned no results
# query Stadtbahn Radl returned no results
# query Regionalbahn Fahrrad returned no results
# query Regionalbahn ebike returned no results
# query Regionalbahn Elektrorad returned no results
# query Regionalbahn Elektrobike returned no results
# query Regionalbahn Elektrofahrrad returned no results
# query Regionalbahn pedelec returned no results
# query Regionalbahn velo returned no results
# query Regionalbahn Mountainbike returned no results
# query Regionalbahn Trekkingbike returned no results
# query Regionalbahn Radl returned no results
# query Straßenbahn bike returned no results
# query Straßenbahn ebike returned no results
# query Straßenbahn Elektrorad returned no results
# query Straßenbahn Elektrobike returned no results
# query Straßenbahn Elektrofahrrad returned no results
# query Straßenbahn pedelec returned no results
# query Straßenbahn velo returned no results
# query Straßenbahn Mountainbike returned no results
# query Straßenbahn Trekkingbike returned no results
# query Straßenbahn Radl returned no results
# query Tram ebike returned no results
# query Tram Elektrorad returned no results
# query Tram Elektrobike returned no results
# query Tram Elektrofahrrad returned no results
# query Tram pedelec returned no results
# query Tram Mountainbike returned no results
# query Tram Trekkingbike returned no results
# query Tram Radl returned no results
# query Bus Elektrorad returned no results
# query Bus Elektrobike returned no results
# query Bus Elektrofahrrad returned no results
# query Bus Mountainbike returned no results
# query Bus Trekkingbike returned no results
# query Bus Radl returned no results
# query Fernbus Fahrrad returned no results
# query Fernbus rad returned no results
# query Fernbus bike returned no results
# query Fernbus ebike returned no results
# query Fernbus Elektrorad returned no results
# query Fernbus Elektrobike returned no results
# query Fernbus Elektrofahrrad returned no results
# query Fernbus pedelec returned no results
# query Fernbus velo returned no results
# query Fernbus Mountainbike returned no results
# query Fernbus Trekkingbike returned no results
# query Fernbus Radl returned no results
# query Stadtbus rad returned no results
# query Stadtbus bike returned no results
# query Stadtbus ebike returned no results
# query Stadtbus Elektrorad returned no results
# query Stadtbus Elektrobike returned no results
# query Stadtbus Elektrofahrrad returned no results
# query Stadtbus pedelec returned no results
# query Stadtbus velo returned no results
# query Stadtbus Mountainbike returned no results
# query Stadtbus Trekkingbike returned no results
# query Stadtbus Radl returned no results
# query bahn Elektrorad returned no results
# query bahn Elektrobike returned no results
# query bahn Elektrofahrrad returned no results
# query bahn Mountainbike returned no results
# query bahn Trekkingbike returned no results
# query bahn Radl returned no results
# query ÖPNV Elektrorad returned no results
# query ÖPNV Elektrobike returned no results
# query ÖPNV Elektrofahrrad returned no results
# query ÖPNV Mountainbike returned no results
# query ÖPNV Trekkingbike returned no results
# query ICE Elektrorad returned no results
# query ICE Elektrobike returned no results
# query ICE Elektrofahrrad returned no results
# query ICE pedelec returned no results
# query ICE Trekkingbike returned no results
# query ICE Radl returned no results
# query IC ebike returned no results
# query IC Elektrorad returned no results
# query IC Elektrobike returned no results
# query IC Elektrofahrrad returned no results
# query IC pedelec returned no results
# query IC Mountainbike returned no results
# query IC Trekkingbike returned no results
# query IC Radl returned no results
# query RE Elektrorad returned no results
# query RE Elektrobike returned no results
# query RE Elektrofahrrad returned no results
# query RE Trekkingbike returned no results
# 1923 tweets where found with 1759 unique tweet_ids

# %%
save_filename = pd.Timestamp.today().strftime('%Y-%m-%d') + '_tweets_DB_Fahrrad'
tweets_data.to_pickle('Tweets/' + save_filename)

# %%
#likes = client.get_liking_users(1512355733555326982)

# %%
#likes.json()

# %% [markdown]
# - Auf Twitter gibt es ca. 20 Tweets pro Tag zum Thema Bahn & Fahrrad. Reicht das?
# - Nur Zugriff auf Daten der letzten 7 Tage

# %% [markdown]
# https://towardsdatascience.com/collect-data-from-twitter-a-step-by-step-implementation-using-tweepy-7526fff2cb31https://towardsdatascience.com/collect-data-from-twitter-a-step-by-step-implementation-using-tweepy-7526fff2cb31
